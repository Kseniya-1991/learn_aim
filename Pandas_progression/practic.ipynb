# %%
import pandas as pd

melb_df = pd.read_csv('data/melb_data_fe.csv',  sep = ',')
display(melb_df.head())
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
#    MeanRoomsSquare AreaRatio  MonthSale  AgeBuilding WeekdaySale  StreetType  \
# 0            25.20 -0.231707          3           46           5          St
# 1            15.80 -0.327660          4          116           5          St
# 2            18.75  0.056338          4          117           0          St
# 3            15.75  0.145455          4           47           0       other
# 4            17.75  0.083969          4            2           2          St
#
#    Weekend
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#
# [5 rows x 26 columns]

# %%
exclude_col = ['Date', 'Bedroom', 'Bathroom', 'Rooms', 'Car' ]
max_count = 150

for col in melb_df.columns:
    if melb_df[col].nunique() < max_count and col not in exclude_col:
        melb_df[col] = melb_df[col].astype('category')
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  object
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
#  16  Longtitude       13580 non-null  float64
#  17  Regionname       13580 non-null  category
#  18  Propertycount    13580 non-null  int64
#  19  MeanRoomsSquare  13580 non-null  float64
#  20  AreaRatio        13580 non-null  float64
#  21  MonthSale        13580 non-null  category
#  22  AgeBuilding      13580 non-null  int64
#  23  WeekdaySale      13580 non-null  category
#  24  StreetType       13580 non-null  category
#  25  Weekend          13580 non-null  category
# dtypes: category(10), float64(8), int64(7), object(1)
# memory usage: 1.8+ MB
# None

# %%
display(melb_df.groupby('Regionname')['Lattitude'].std().sort_values(ascending=False))
# Out:
# C:\Users\Kaiya07\AppData\Local\Temp\ipykernel_13564\500140908.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   display(melb_df.groupby('Regionname')['Lattitude'].std().sort_values(ascending=False))
# Regionname
# Eastern Victoria              0.147067
# Northern Victoria             0.084455
# South-Eastern Metropolitan    0.073411
# Western Metropolitan          0.051251
# Northern Metropolitan         0.049639
# Eastern Metropolitan          0.047890
# Southern Metropolitan         0.043080
# Western Victoria              0.011579
# Name: Lattitude, dtype: float64

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'])
date1 = pd.to_datetime('2017-05-01')
date2 = pd.to_datetime('2017-09-01')
mask = (date1 <= melb_df['Date']) & (melb_df['Date']<= date2)
melb_df[mask].groupby('SellerG')['Price'].sum().sort_values(ascending=True)
# Out:
# C:\Users\Kaiya07\AppData\Local\Temp\ipykernel_13564\3849703747.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df[mask].groupby('SellerG')['Price'].sum().sort_values(ascending=True)
# SellerG
# LITTLE             2742000.0
# Cayzer             4439000.0
# Burnham            4550500.0
# Moonee             7328000.0
# Thomson            8332000.0
# Bells              8656000.0
# Alexkarbon        10985000.0
# McDonald          14637500.0
# Rendina           15422276.0
# Nick              16890000.0
# Douglas           18341000.0
# Buckingham        19033000.0
# C21               19515000.0
# Eview             19791500.0
# Collins           20217000.0
# Philip            22051800.0
# Chisholm          23225000.0
# Williams          23297000.0
# Love              23365500.0
# Purplebricks      23401000.0
# O'Brien           23855508.0
# HAR               25568000.0
# Village           26473000.0
# RW                29261000.0
# Raine             30687700.0
# Stockdale         35409800.0
# Sweeney           36882750.0
# Gary              39138400.0
# Hodges            43231000.0
# YPA               46354350.0
# Miles             47582000.0
# Kay               48569500.0
# RT                50498000.0
# Brad              55955000.0
# Jas               59281600.0
# Harcourts         68720250.0
# McGrath           78386500.0
# Greg              85621000.0
# Woodards          85977500.0
# Noel              88129800.0
# Fletchers        108847700.0
# Biggin           110429500.0
# Buxton           219104000.0
# Ray              249572986.0
# Marshall         253957888.0
# hockingstuart    282834310.0
# Barry            296723050.0
# other            365038432.0
# Nelson           379767500.0
# Jellis           414121833.0
# Name: Price, dtype: float64

# %%
melb_df.columns
# Out:
# Index(['Suburb', 'Rooms', 'Type', 'Price', 'Method', 'SellerG', 'Date',
#        'Distance', 'Postcode', 'Bedroom', 'Bathroom', 'Car', 'Landsize',
#        'BuildingArea', 'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname',
#        'Propertycount', 'MeanRoomsSquare', 'AreaRatio', 'MonthSale',
#        'AgeBuilding', 'WeekdaySale', 'StreetType', 'Weekend'],
#       dtype='object')

# %%
melb_dfp = melb_df.groupby(['Type', 'Rooms'])['BuildingArea'].median()
display(melb_dfp.unstack())
# Out:
# C:\Users\Kaiya07\AppData\Local\Temp\ipykernel_13564\2351386694.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_dfp = melb_df.groupby(['Type', 'Rooms'])['BuildingArea'].median()
# Rooms         1      2      3      4      5      6      7      8      10
# Type
# house      126.0  126.0  126.0  141.0  177.0  126.0  216.5  126.0  126.0
# townhouse   88.0  114.0  126.0  159.5  152.0    NaN    NaN    NaN    NaN
# unit        69.5  110.0  126.0  126.0    NaN  171.0    NaN  126.0    NaN

# %%
pivot = melb_df.pivot_table(
    values='Price',
    index='SellerG',
    columns='Type',
    aggfunc='median',
)
max_unit_price = pivot['unit'].max()
print(pivot[pivot['unit'] == max_unit_price].index[0])
# Out:
# Nick
# C:\Users\Kaiya07\AppData\Local\Temp\ipykernel_13564\1156440549.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = melb_df.pivot_table(

# %%
dates = pd.read_csv('data\movies_data\dates.csv', sep= ',')
movies = pd.read_csv('data\movies_data\movies.csv', sep= ',')

ratings1 = pd.read_csv('data\movies_data\\ratings1.csv', sep= ',')
ratings2 = pd.read_csv('data\movies_data\\ratings2.csv', sep= ',')

# %%
dates['Datetype']= pd.to_datetime(dates['date'])
dates['Datetype'].dt.year.value_counts()
# Out:
# Datetype
# 2000    10061
# 2017     8198
# 2007     7114
# 2016     6703
# 2015     6616
# 2018     6418
# 1996     6040
# 2005     5813
# 2012     4656
# 2008     4351
# 2009     4158
# 2006     4059
# 2003     4014
# 2001     3922
# 2002     3478
# 2004     3279
# 1999     2439
# 2010     2301
# 1997     1916
# 2011     1690
# 2013     1664
# 2014     1439
# 1998      507
# Name: count, dtype: int64

# %%
ratings = pd.concat([ratings1, ratings2], ignore_index=True)
ratings
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100832     610   166534     4.0
# 100833     610   168248     5.0
# 100834     610   168250     5.0
# 100835     610   168252     5.0
# 100836     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
print('Число строк в таблице ratings: ', ratings.shape[0])
print('Число строк в таблице dates: ', dates.shape[0])
print(ratings.shape[0] == dates.shape[0])
# Out:
# Число строк в таблице ratings:  100837
# Число строк в таблице dates:  100836
# False

# %%
display(ratings1.tail(1))
display(ratings2.head(1))
# Out:
#        userId  movieId  rating
# 40000     274     5621     2.0
#    userId  movieId  rating
# 0     274     5621     2.0

# %%
ratings = ratings.drop_duplicates(ignore_index=True)
print('Число строк в таблице ratings: ', ratings.shape[0])
# Число строк в таблице ratings: 100836
# Out:
# Число строк в таблице ratings:  100836

# %%
dates.head()
# Out:
#                   date            Datetype
# 0  2000-07-30 18:45:03 2000-07-30 18:45:03
# 1  2000-07-30 18:20:47 2000-07-30 18:20:47
# 2  2000-07-30 18:37:04 2000-07-30 18:37:04
# 3  2000-07-30 19:03:35 2000-07-30 19:03:35
# 4  2000-07-30 18:48:51 2000-07-30 18:48:51

# %%
ratings_dates = pd.concat([ratings, dates], axis=1)
display(ratings_dates.tail(7))
# Out:
#         userId  movieId  rating                 date            Datetype
# 100829     610   164179     5.0  2017-05-03 21:07:11 2017-05-03 21:07:11
# 100830     610   166528     4.0  2017-05-04 06:29:25 2017-05-04 06:29:25
# 100831     610   166534     4.0  2017-05-03 21:53:22 2017-05-03 21:53:22
# 100832     610   168248     5.0  2017-05-03 22:21:31 2017-05-03 22:21:31
# 100833     610   168250     5.0  2017-05-08 19:50:47 2017-05-08 19:50:47
# 100834     610   168252     5.0  2017-05-03 21:19:12 2017-05-03 21:19:12
# 100835     610   170875     3.0  2017-05-03 21:20:15 2017-05-03 21:20:15

# %%
joined_false = ratings_dates.join(
    movies,
    rsuffix='_right',
    how='left'
)
display(joined_false)
# Out:
#         userId  movieId  rating                 date            Datetype  \
# 0            1        1     4.0  2000-07-30 18:45:03 2000-07-30 18:45:03
# 1            1        3     4.0  2000-07-30 18:20:47 2000-07-30 18:20:47
# 2            1        6     4.0  2000-07-30 18:37:04 2000-07-30 18:37:04
# 3            1       47     5.0  2000-07-30 19:03:35 2000-07-30 19:03:35
# 4            1       50     5.0  2000-07-30 18:48:51 2000-07-30 18:48:51
# ...        ...      ...     ...                  ...                 ...
# 100831     610   166534     4.0  2017-05-03 21:53:22 2017-05-03 21:53:22
# 100832     610   168248     5.0  2017-05-03 22:21:31 2017-05-03 22:21:31
# 100833     610   168250     5.0  2017-05-08 19:50:47 2017-05-08 19:50:47
# 100834     610   168252     5.0  2017-05-03 21:19:12 2017-05-03 21:19:12
# 100835     610   170875     3.0  2017-05-03 21:20:15 2017-05-03 21:20:15
#
#         movieId_right                               title  \
# 0                 1.0                    Toy Story (1995)
# 1                 2.0                      Jumanji (1995)
# 2                 3.0             Grumpier Old Men (1995)
# 3                 4.0            Waiting to Exhale (1995)
# 4                 5.0  Father of the Bride Part II (1995)
# ...               ...                                 ...
# 100831            NaN                                 NaN
# 100832            NaN                                 NaN
# 100833            NaN                                 NaN
# 100834            NaN                                 NaN
# 100835            NaN                                 NaN
#
#                                              genres
# 0       Adventure|Animation|Children|Comedy|Fantasy
# 1                        Adventure|Children|Fantasy
# 2                                    Comedy|Romance
# 3                              Comedy|Drama|Romance
# 4                                            Comedy
# ...                                             ...
# 100831                                          NaN
# 100832                                          NaN
# 100833                                          NaN
# 100834                                          NaN
# 100835                                          NaN
#
# [100836 rows x 8 columns]

# %%
joined = ratings_dates.join(
    movies.set_index('movieId'),
    on='movieId',
    how='left'
)
display(joined.head())
# Out:
#    userId  movieId  rating                 date            Datetype  \
# 0       1        1     4.0  2000-07-30 18:45:03 2000-07-30 18:45:03
# 1       1        3     4.0  2000-07-30 18:20:47 2000-07-30 18:20:47
# 2       1        6     4.0  2000-07-30 18:37:04 2000-07-30 18:37:04
# 3       1       47     5.0  2000-07-30 19:03:35 2000-07-30 19:03:35
# 4       1       50     5.0  2000-07-30 18:48:51 2000-07-30 18:48:51
#
#                          title                                       genres
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller

# %%
merged = ratings_dates.merge(
    movies,
    on='movieId',
    how='left'
)
display(merged.head())
# Out:
#    userId  movieId  rating                 date            Datetype  \
# 0       1        1     4.0  2000-07-30 18:45:03 2000-07-30 18:45:03
# 1       1        3     4.0  2000-07-30 18:20:47 2000-07-30 18:20:47
# 2       1        6     4.0  2000-07-30 18:37:04 2000-07-30 18:37:04
# 3       1       47     5.0  2000-07-30 19:03:35 2000-07-30 19:03:35
# 4       1       50     5.0  2000-07-30 18:48:51 2000-07-30 18:48:51
#
#                          title                                       genres
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller

# %%
merge_ratings = ratings1.merge(ratings2, how='outer')
print('Число строк в таблице merge_ratings: ', merge_ratings.shape[0])
display(merge_ratings)
# Out:
# Число строк в таблице merge_ratings:
#  100836
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
# 100835     610   170875     3.0
#
# [100836 rows x 3 columns]

# %%
items_df = pd.DataFrame({
    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394], 
    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],
    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]
})
items_df
# Out:
#    item_id   vendor  stock_count
# 0   417283  Samsung           54
# 1   849734       LG           33
# 2   132223    Apple          122
# 3   573943    Apple           18
# 4    19475       LG          102
# 5  3294095    Apple           43
# 6   382043  Samsung           77
# 7   302948  Samsung          143
# 8   100132       LG           60
# 9   312394      ZTE           19

# %%
purchase_df = pd.DataFrame({
    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],
    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132], 
    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]
})
purchase_df
# Out:
#    purchase_id  item_id  price
# 0          101   417283  13900
# 1          101   849734   5330
# 2          101   132223  38200
# 3          112   573943  49990
# 4          121    19475   9890
# 5          145  3294095  33000
# 6          145   382043  67500
# 7          145   302948  34500
# 8          145   103845  89900
# 9          221   100132  11400

# %%
merged = items_df.merge(purchase_df, on= 'item_id', how = 'inner')
merged
# Out:
#    item_id   vendor  stock_count  purchase_id  price
# 0   417283  Samsung           54          101  13900
# 1   849734       LG           33          101   5330
# 2   132223    Apple          122          101  38200
# 3   573943    Apple           18          112  49990
# 4    19475       LG          102          121   9890
# 5  3294095    Apple           43          145  33000
# 6   382043  Samsung           77          145  67500
# 7   302948  Samsung          143          145  34500
# 8   100132       LG           60          221  11400

# %%
income = sum(merged['stock_count'] * merged['price'])
income
# Out:
# 19729490
